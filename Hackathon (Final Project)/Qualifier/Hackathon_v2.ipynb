# %%
import pandas as pd

# %%
dfFly = pd.read_csv('flights-selected/1912_bts_flights.csv')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dfFly.head()
# Out:
#    DayofMonth  DayOfWeek  FlightDate Marketing_Airline_Network  \
# 0          31          2  2019-12-31                        AA
# 1           1          7  2019-12-01                        AA
# 2           4          3  2019-12-04                        AA
# 3           5          4  2019-12-05                        AA
# 4           6          5  2019-12-06                        AA
#
#   Operated_or_Branded_Code_Share_Partners  Flight_Number_Marketing_Airline  \
# 0                                      AA                             1583
# 1                                      AA                             1584
# 2                                      AA                             1584
# 3                                      AA                             1584
# 4                                      AA                             1584
#
#   Origin OriginCityName OriginState Dest  ... AirTime Flights  Distance  \
# 0    PHX    Phoenix, AZ          AZ  ORD  ...   170.0     1.0    1440.0
# 1    AUS     Austin, TX          TX  DFW  ...    36.0     1.0     190.0
# 2    AUS     Austin, TX          TX  DFW  ...    38.0     1.0     190.0
# 3    AUS     Austin, TX          TX  DFW  ...    43.0     1.0     190.0
# 4    AUS     Austin, TX          TX  DFW  ...    33.0     1.0     190.0
#
#    DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0              6           NaN           NaN       NaN            NaN
# 1              1           6.0           0.0       0.0            0.0
# 2              1           NaN           NaN       NaN            NaN
# 3              1           NaN           NaN       NaN            NaN
# 4              1         153.0           0.0       0.0            0.0
#
#   LateAircraftDelay  DivAirportLandings
# 0               NaN                   0
# 1              21.0                   0
# 2               NaN                   0
# 3               NaN                   0
# 4               3.0                   0
#
# [5 rows x 45 columns]

# %%
y = dfFly['DepDel15']
X = dfFly.drop(['DepDel15','FlightDate','DepDelay','DepDelayMinutes','DepartureDelayGroups','ArrDelay','ArrDelayMinutes','ArrivalDelayGroups',
                'ArrDel15','CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay'], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

mdlLrFly = LogisticRegression()
mdlLrFly.fit(X_train, y_train)
y_test_pred = mdlLrFly.predict(X_test)
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         4
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
